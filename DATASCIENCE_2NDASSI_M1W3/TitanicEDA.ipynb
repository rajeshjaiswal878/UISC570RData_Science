# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ### Rajesh Jaiswal
# #### Second Assignment

# %%
data=pd.read_csv('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %% [markdown]
# ## Description of Full Data
#  We are Exploring whole data as one variable,before starting EDA on an each variable.
#  We will perform below steps:
# <li> Data Shape;
# <li> Describe whole data without missing data handlling:

# %%
data.shape
# Out:
# (891, 12)

# %%
data.describe()
# Out:
# /Users/rajeshjaiswal/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000         NaN    0.000000
# 50%     446.000000    0.000000    3.000000         NaN    0.000000
# 75%     668.500000    1.000000    3.000000         NaN    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# ...

# %%
data.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11ff2c5c0>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x120747400>]], dtype=object)

# %% [markdown]
# <h2>Description of Full Data after go through:</h2>
# We are Exploring whole data as one variable,
# before starting EDA on an each variable. We will perform below steps:
# <li>Data Shape:(891, 12)
# <li>Describe whole data without missing data handlling: Result in out[7]

# %% [markdown]
# ----------------------------------------------------------
# ## EDA of PassengerID: Before Process
#
# ### Variable Name: PassengerID
#
# <li>Variable Type:
# <li>If Categorical Then Categories?
# <li>If Not..... Then Min,Max,Mean and Standard Deviation
# <li>Missing Values ?
# <li>Histograms?

# %%
data.PassengerId.value_counts()
# Out:
# 891    1
# 293    1
# 304    1
# 303    1
# 302    1
# 301    1
# 300    1
# 299    1
# 298    1
# 297    1
# 296    1
# 295    1
# 294    1
# 292    1
# 306    1
# 291    1
# 290    1
# 289    1
# 288    1
# 287    1
# 286    1
# 285    1
# 284    1
# 283    1
# 282    1
# 281    1
# 305    1
# 307    1
# 279    1
# 321    1
#       ..
# 561    1
# 560    1
# 584    1
# 585    1
# 586    1
# 587    1
# 610    1
# 609    1
# 608    1
# 607    1
# 606    1
# 605    1
# 604    1
# 603    1
# 602    1
# 601    1
# 600    1
# 599    1
# 598    1
# 597    1
# 596    1
# 595    1
# 594    1
# 593    1
# 592    1
# 591    1
# 590    1
# 589    1
# 588    1
# 1      1
# Name: PassengerId, dtype: int64

# %%
data.PassengerId.describe()
# Out:
# count    891.000000
# mean     446.000000
# std      257.353842
# min        1.000000
# 25%      223.500000
# 50%      446.000000
# 75%      668.500000
# max      891.000000
# Name: PassengerId, dtype: float64

# %%
data[data.PassengerId.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data.PassengerId.value_counts().plot(kind='bar')

# %%
data.PassengerId.hist(bins=5)

# %% [markdown]
# <h2>EDA of PassengerID: After Process</h2>
# <h3>Variable Name: PassengerID</h3>
# <li>Variable Type: Continuous as per out[9]
# <li>If Categorical Then Categories?No...It is Continuous variable
# <li>If Not..... Then Min,Max,Mean and Standard Deviation as per out[10]
#     Min:1.000000
#     Max:891.000000
#     Mean:446.000000
#     Standard Deviation:257.353842
# <li>Missing Values ? No Missing Values as per out[12]
# <li>Histograms? Very Big histogram due to which it is black
# <h3>------------------------------------------------------------------</h3>

# %% [markdown]
# ## EDA of Survived: Before Process
#
# ### Variable Name: Survived
# <li>Variable Type:
# <li>If Categorical Then Categories?
# <li>If Not..... Then Min,Max,Mean and Standard Deviation
# <li>Missing Values ?
# <li>Histograms?

# %%
data.Survived.value_counts()
# Out:
# 0    549
# 1    342
# Name: Survived, dtype: int64

# %%
data[data.Survived.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data.Survived.value_counts().plot(kind='bar',title='Survivorship')

# %%
data.Survived.hist()

# %% [markdown]
# ## EDA of Survived: After Process
#
# ### Variable Name: Survived
# <li>Variable Type: <strong>Categorical</strong>
# <li>If Categorical Then Categories?:<strong>Categories:2  0-Not Survived,1-Survived as per out [18]</strong>
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:<strong></strong>
# <li>Missing Values ?: <strong> No Missing values as per out[20]</strong>
# <li>Histograms?:<strong> out[21]</strong>
# <h3>-------------------------------------------------------------------------</h3>

# %% [markdown]
# <h3>-------------------------------------------------------------------------</h3>
# ## EDA of Pclass: Before Process
#
# ### Variable Name: Pclass
# <li>Variable Type:
# <li>If Categorical Then Categories?:
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:
# <li>Missing Values ?:
# <li>Histograms?:

# %%
data.Pclass.value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
data[data.Pclass.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data.Pclass.value_counts().plot(kind='bar',title='Class_Distribution')

# %% [markdown]
# ## EDA of Pclass: After Process
#
# ### Variable Name: Pclass
# <li>Variable Type: <strong>Categorical</strong>
# <li>If Categorical Then Categories?:<strong>Categories:3   1-first,2-Second and 3-Lower as per out [22]</strong>
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:<strong> This Is Categorical</strong>
# <li>Missing Values ?: <strong> No Missing values as per out[23]</strong>
# <li>Histograms?:<strong> out[24]</strong>
# <h3>-------------------------------------------------------------------------</h3>

# %%
data.Pclass.hist()

# %% [markdown]
# <h3>-------------------------------------------------------------------------</h3>
# ## EDA of Sex: Before Process
#
# ### Variable Name: Sex
# <li>Variable Type:
# <li>If Categorical Then Categories?:
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:
# <li>Missing Values ?:
# <li>Histograms?:

# %%
data.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
data[data.Sex.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data.Sex.value_counts().plot(kind='bar',title='Gender_Distribution')

# %% [markdown]
# ## EDA of Sex: After Process
#
# ### Variable Name: Sex
# <li>Variable Type: <strong>Categorical</strong>
# <li>If Categorical Then Categories?:<strong>Categories:2   1-Male,2-Female as per out [26]</strong>
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:<strong> This Is Categorical</strong>
# <li>Missing Values ?: <strong> No Missing values as per out[27]</strong>
# <li>Histograms?:<strong> out[28]</strong>
# <h3>-------------------------------------------------------------------------</h3>

# %% [markdown]
# <h3>-------------------------------------------------------------------------</h3>
# ## EDA of Age: Before Process
#
# ### Variable Name: Age
# <li>Variable Type:
# <li>If Categorical Then Categories?:
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:
# <li>Missing Values ?:
# <li>Histograms?:

# %%
data.Age.value_counts()
# Out:
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
# 30.00    25
# 21.00    24
# 25.00    23
# 36.00    22
# 29.00    20
# 27.00    18
# 35.00    18
# 26.00    18
# 32.00    18
# 31.00    17
# 16.00    17
# 23.00    15
# 20.00    15
# 34.00    15
# 33.00    15
# 39.00    14
# 17.00    13
# 40.00    13
# 42.00    13
# 45.00    12
# 38.00    11
# 50.00    10
# 2.00     10
# 4.00     10
# 48.00     9
#          ..
# 0.75      2
# 45.50     2
# 64.00     2
# 30.50     2
# 0.83      2
# 32.50     2
# 40.50     2
# 71.00     2
# 28.50     2
# 63.00     2
# 59.00     2
# 57.00     2
# 55.00     2
# 70.00     2
# 55.50     1
# 24.50     1
# 34.50     1
# 0.92      1
# 36.50     1
# 0.42      1
# 23.50     1
# 12.00     1
# 20.50     1
# 14.50     1
# 80.00     1
# 74.00     1
# 70.50     1
# 66.00     1
# 53.00     1
# 0.67      1
# Name: Age, dtype: int64

# %%
data[data.Age.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 17            18         1       2
# 19            20         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 31            32         1       1
# 32            33         1       3
# 36            37         1       3
# 42            43         0       3
# 45            46         0       3
# 46            47         0       3
# 47            48         1       3
# 48            49         0       3
# 55            56         1       1
# 64            65         0       1
# 65            66         1       3
# 76            77         0       3
# 77            78         0       3
# 82            83         1       3
# 87            88         0       3
# 95            96         0       3
# 101          102         0       3
# 107          108         1       3
# 109          110         1       3
# ...

# %% [markdown]
# ### Before Handlling Missing Data Value

# %%
data.Age.describe()
# Out:
# /Users/rajeshjaiswal/anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
# count    714.000000
# mean      29.699118
# std       14.526497
# min        0.420000
# 25%             NaN
# 50%             NaN
# 75%             NaN
# max       80.000000
# Name: Age, dtype: float64

# %% [markdown]
# ### After handlling Missing Data Value
#
# <li><strong> Used Data Average method to handle Null Values</strong>
#
# Steps:--
#
# <li> 1st We calculate mean value of Age
# <li> 2nd We use Average Age value at null value.
# <li> 3rd Again Calculate Min,Max,Mean,Standard Deviation.

# %%
AvgAge = data.Age.mean()

# %%
data.Age = data.Age.fillna(value=AvgAge)

# %%
data[data.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data.Age.describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
data.Age.value_counts().plot(kind='bar',title='Age_Distribution')

# %%
data.Age.hist()

# %% [markdown]
# ## EDA of Age: After Process
#
# ### Variable Name: Age
# <li>Variable Type: <strong>Continuous</strong>
# <li>If Categorical Then Categories?:<strong>COntinuous so No Categories as per out [29]</strong>
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:</br>
#  <li><strong>                         Before Handlling Missing Data    After                </strong></br>
#  <li><Strong>Min                      0.420000                         0.420000             </Strong></br>
#  <li><strong>Max                      80.000000                        80.000000            </strong></br>
#  <li><Strong>Mean                     29.699118                        29.699118            </Strong></br>
#  <li><strong>Standard Deviation       14.526497                        13.002015            </strong>
# <li>Missing Values ?: <strong> 177 as per out[32]</strong>
# <li>Histograms?:<strong> out[45]</strong>
# <h3>-------------------------------------------------------------------------</h3>

# %% [markdown]
# <h3>-------------------------------------------------------------------------</h3>
# ## EDA of SibSp: Before Process
#
# ### Variable Name:SibSp
# <li>Variable Type:
# <li>If Categorical Then Categories?:
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:
# <li>Missing Values ?:
# <li>Histograms?:

# %%
data.SibSp.value_counts()
# Out:
# 0    608
# 1    209
# 2     28
# 4     18
# 3     16
# 8      7
# 5      5
# Name: SibSp, dtype: int64

# %%
data[data.SibSp.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data.SibSp.value_counts().plot(kind='bar',title='SibSp_Distribution')

# %%
data.SibSp.hist()

# %% [markdown]
# ## EDA of 	SibSp: After Process
#
# ### Variable Name: 	SibSp
# <li>Variable Type: <strong>Categorical</strong>
# <li>If Categorical Then Categories?:<strong>Categories:6  0,1,2,3,4,5 as per out [47]</strong>
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:<strong>No This is Categorical</strong>
# <li>Missing Values ?: <strong> No Missing values as per out[50]</strong>
# <li>Histograms?:<strong> out[53]</strong>
# <h3>-------------------------------------------------------------------------</h3>

# %% [markdown]
# <h3>-------------------------------------------------------------------------</h3>
# ## EDA of Parch: Before Process
#
# ### Variable Name:Parch
# <li>Variable Type:
# <li>If Categorical Then Categories?:
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:
# <li>Missing Values ?:
# <li>Histograms?:

# %%
data.Parch.value_counts()
# Out:
# 0    678
# 1    118
# 2     80
# 5      5
# 3      5
# 4      4
# 6      1
# Name: Parch, dtype: int64

# %%
data[data.Parch.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data.Parch.value_counts().plot(kind='bar',title='Parch_Distribution')

# %%
data.Parch.hist()

# %% [markdown]
# ## EDA of Parch: After Process
#
# ### Variable Name: Parch
# <li>Variable Type: <strong>Categorical</strong>
# <li>If Categorical Then Categories?:<strong>Categories:7  0,1,2,3,4,5,6 as per out [55]</strong>
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:<strong>No This is Categorical</strong>
# <li>Missing Values ?: <strong> No Missing values as per out[56]</strong>
# <li>Histograms?:<strong> out[57]</strong>
# <h3>-------------------------------------------------------------------------</h3>

# %% [markdown]
# <h3>-------------------------------------------------------------------------</h3>
# ## EDA of Ticket: Before Process
#
# ### Variable Name: Ticket
# <li>Variable Type:
# <li>If Categorical Then Categories?:
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:
# <li>Missing Values ?:
# <li>Histograms?:

# %%
data.Ticket.value_counts()
# Out:
# 347082               7
# CA. 2343             7
# 1601                 7
# CA 2144              6
# 3101295              6
# 347088               6
# 382652               5
# S.O.C. 14879         5
# 17421                4
# 349909               4
# 113760               4
# LINE                 4
# 19950                4
# 113781               4
# PC 17757             4
# W./C. 6608           4
# 2666                 4
# 4133                 4
# 347077               4
# 13502                3
# 110413               3
# C.A. 31921           3
# 29106                3
# 230080               3
# PC 17582             3
# 248727               3
# 110152               3
# 24160                3
# 35273                3
# SC/Paris 2123        3
#                     ..
# A/4. 20589           1
# A./5. 3235           1
# CA. 2314             1
# 349240               1
# STON/O 2. 3101289    1
# 373450               1
# A/5. 13032           1
# 330932               1
# 347076               1
# ...

# %%
data[data.Ticket.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data.Ticket.describe()
# Out:
# count        891
# unique       681
# top       347082
# freq           7
# Name: Ticket, dtype: object

# %%
data.Ticket.value_counts().plot(kind='bar',title='Ticket_Distribution')

# %% [markdown]
# ## EDA of Ticket: After Process
#
# ### Variable Name: Ticket
# <li>Variable Type: <strong>Continuous</strong>
# <li>If Categorical Then Categories?:<strong>COntinuous so No Categories as per out [58]</strong>
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:<strong> count-891,
# unique-681,
# top-347082,
# freq-7</strong>
# <li>Missing Values ?: <strong> No Missing values as per out[59]</strong>
# <li>Histograms?:<strong> out[61]</strong>
# <h3>-------------------------------------------------------------------------</h3>

# %% [markdown]
# <h3>-------------------------------------------------------------------------</h3>
# ## EDA of 	Fare: Before Process
#
# ### Variable Name: 	Fare
# <li>Variable Type:
# <li>If Categorical Then Categories?:
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:
# <li>Missing Values ?:
# <li>Histograms?:

# %%
data.Fare.value_counts()
# Out:
# 8.0500      43
# 13.0000     42
# 7.8958      38
# 7.7500      34
# 26.0000     31
# 10.5000     24
# 7.9250      18
# 7.7750      16
# 26.5500     15
# 7.2292      15
# 0.0000      15
# 7.2500      13
# 7.8542      13
# 8.6625      13
# 7.2250      12
# 9.5000       9
# 16.1000      9
# 24.1500      8
# 15.5000      8
# 56.4958      7
# 14.5000      7
# 7.0500       7
# 52.0000      7
# 31.2750      7
# 69.5500      7
# 14.4542      7
# 7.7958       6
# 26.2500      6
# 30.0000      6
# 27.9000      6
#             ..
# 211.5000     1
# 12.2750      1
# 8.6542       1
# 6.9500       1
# 22.0250      1
# 7.1417       1
# 10.1708      1
# 17.4000      1
# 8.3000       1
# 16.0000      1
# 10.5167      1
# 15.0458      1
# 50.4958      1
# 8.4042       1
# 26.2833      1
# 12.6500      1
# 8.7125       1
# 22.5250      1
# 15.7500      1
# 9.2167       1
# 21.6792      1
# 14.1083      1
# 15.1000      1
# 7.3125       1
# 8.1125       1
# 13.8583      1
# 34.6542      1
# ...

# %%
data[data.Fare.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data.Fare.describe()
# Out:
# count    891.000000
# mean      32.204208
# std       49.693429
# min        0.000000
# 25%        7.910400
# 50%       14.454200
# 75%       31.000000
# max      512.329200
# Name: Fare, dtype: float64

# %%
data.Fare.value_counts().plot(kind='bar',title='Fare_Distribution')

# %%
data.Fare.hist()

# %%
data[data.Fare==0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %% [markdown]
# ## EDA of Fare: After Process
#
# ### Variable Name:Fare
# <li>Variable Type: <strong>Continuous</strong>
# <li>If Categorical Then Categories?:<strong>COntinuous so No Categories as per out [62]</strong>
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:<strong>
# mean      32.204208,
# std       49.693429,
# min        0.000000,
# max      512.329200</strong>
# <li>Missing Values ?: <strong> No Missing values as per out[65]</strong>
# <li>Histograms?:<strong> out[65]</strong>
# <h3>-------------------------------------------------------------------------</h3>

# %% [markdown]
# <h3>-------------------------------------------------------------------------</h3>
# ## EDA of Cabin: Before Process
#
# ### Variable Name: Cabin
# <li>Variable Type:
# <li>If Categorical Then Categories?:
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:
# <li>Missing Values ?:
# <li>Histograms?:

# %%
data.Cabin.value_counts()
# Out:
# B96 B98            4
# G6                 4
# C23 C25 C27        4
# F2                 3
# E101               3
# F33                3
# D                  3
# C22 C26            3
# C93                2
# E67                2
# B5                 2
# E33                2
# B58 B60            2
# B49                2
# F G73              2
# B35                2
# C123               2
# B77                2
# B57 B59 B63 B66    2
# B20                2
# C124               2
# D35                2
# C65                2
# B18                2
# B28                2
# E24                2
# C52                2
# B51 B53 B55        2
# D17                2
# D33                2
#                   ..
# C30                1
# D48                1
# A31                1
# F E69              1
# C90                1
# C46                1
# C82                1
# B80                1
# B37                1
# D47                1
# B41                1
# B69                1
# ...

# %%
data[data.Cabin.isnull()]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 22            23         1       3
# 24            25         0       3
# 25            26         1       3
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# ...

# %%
data.Cabin.describe()
# Out:
# count         204
# unique        147
# top       B96 B98
# freq            4
# Name: Cabin, dtype: object

# %%
data.Cabin.value_counts().plot(kind='bar',title='Cabin_Distribution')

# %% [markdown]
# ## EDA of Cabin: After Process
#
# ### Variable Name: Cabin
# <li>Variable Type: <strong>Continuous</strong>
# <li>If Categorical Then Categories?:<strong>No this is Continuous</strong>
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:<strong>count         204,
# unique        147,
# top       B96 B98,
# freq            4</strong>
# <li>Missing Values ?: <strong> 687 rows as per out[70]</strong>
# <li>Histograms?:<strong> out[74]</strong>
# <h3>-------------------------------------------------------------------------</h3>

# %% [markdown]
# <h3>-------------------------------------------------------------------------</h3>
# ## EDA of Embarked: Before Process
#
# ### Variable Name: Embarked
# <li>Variable Type:
# <li>If Categorical Then Categories?:
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:
# <li>Missing Values ?:
# <li>Histograms?:

# %%
data.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data[data.Embarked.isnull()]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
data.Embarked.value_counts().plot(kind='bar',title='EM_Distribution')

# %% [markdown]
# ## EDA of Embarked: After Process
#
# ### Variable Name: Embarked
# <li>Variable Type: <strong>Categorical</strong>
# <li>If Categorical Then Categories?:<strong>Categories:3  S,C,Q as per out [75]</strong>
# <li>If Not..... Then Min,Max,Mean and Standard Deviation:<strong>No This is Categorical</strong>
# <li>Missing Values ?: <strong> 2 as per out[77]</strong>
# <li>Histograms?:<strong> out[81]</strong>
# <h3>-------------------------------------------------------------------------</h3>

# %% [markdown]
# <h3>-----------------------------Other Manipulation--------------------------------------------</h3>
# ## EDA Extra  Manipulation Process

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data=pd.read_csv('train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
data[(data.Sex =='female')&(data.Pclass==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 11            12         1       1
# 31            32         1       1
# 52            53         1       1
# 61            62         1       1
# 88            89         1       1
# 136          137         1       1
# 151          152         1       1
# 166          167         1       1
# 177          178         0       1
# 194          195         1       1
# 195          196         1       1
# 215          216         1       1
# 218          219         1       1
# 230          231         1       1
# 256          257         1       1
# 257          258         1       1
# 258          259         1       1
# 268          269         1       1
# 269          270         1       1
# 275          276         1       1
# 290          291         1       1
# 291          292         1       1
# 297          298         0       1
# ...

# %% [markdown]
# ### Number of people who travelling with Sibling or Spouse

# %%
data[data.SibSp>0]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 7              8         0       3
# 9             10         1       2
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# 18            19         0       3
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 35            36         0       1
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 46            47         0       3
# 48            49         0       3
# 49            50         0       3
# 50            51         0       3
# 52            53         1       1
# ...

# %% [markdown]
# ### Number of people Travelling with atleast one Parent

# %%
data[data.Parch>=1]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 43            44         1       2
# 50            51         0       3
# 54            55         0       1
# 58            59         1       2
# 59            60         0       3
# 63            64         0       3
# 65            66         1       3
# 68            69         1       3
# 71            72         0       3
# 78            79         1       2
# 86            87         0       3
# 88            89         1       1
# 93            94         0       3
# 97            98         1       1
# 98            99         1       2
# 102          103         0       1
# 118          119         0       1
# ...

# %% [markdown]
# ### Number of people Travelling Alone

# %%
data[(data.SibSp==0)&(data.Parch==0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 2              3         1       3
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 11            12         1       1
# 12            13         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 26            27         0       3
# 28            29         1       3
# 29            30         0       3
# 30            31         0       1
# 32            33         1       3
# 33            34         0       2
# 36            37         1       3
# 37            38         0       3
# 42            43         0       3
# 44            45         1       3
# 45            46         0       3
# ...

# %% [markdown]
# ### Number of people travelling with (their siblings/spouse+at least one parent=Family)

# %%
data[(data.SibSp>=1)&(data.Parch>=1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 43            44         1       2
# 50            51         0       3
# 58            59         1       2
# 59            60         0       3
# 63            64         0       3
# 65            66         1       3
# 68            69         1       3
# 71            72         0       3
# 86            87         0       3
# 88            89         1       1
# 93            94         0       3
# 119          120         0       3
# 128          129         1       3
# 145          146         0       2
# 147          148         0       3
# 159          160         0       3
# 164          165         0       3
# 167          168         0       3
# ...

# %%
DataFamily=data[(data.SibSp>=1)|(data.Parch>=1)]

# %%
DataFamily
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 13            14         0       3
# 16            17         0       3
# 18            19         0       3
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 31            32         1       1
# 34            35         0       1
# 35            36         0       1
# 38            39         0       3
# 39            40         1       3
# 40            41         0       3
# 41            42         0       2
# 43            44         1       2
# 46            47         0       3
# 48            49         0       3
# 49            50         0       3
# 50            51         0       3
# ...

# %%
DataFamily.Age.hist()

# %%
DataFamily.Pclass.hist()

# %% [markdown]
# ### Number of children travelling (Considering Age 0-18 years excluding null age)

# %%
ChiTrv=data[data.Age<=18]

# %%
ChiTrv
# Out:
#      PassengerId  Survived  Pclass  \
# 7              8         0       3
# 9             10         1       2
# 10            11         1       3
# 14            15         0       3
# 16            17         0       3
# 22            23         1       3
# 24            25         0       3
# 38            39         0       3
# 39            40         1       3
# 43            44         1       2
# 49            50         0       3
# 50            51         0       3
# 58            59         1       2
# 59            60         0       3
# 63            64         0       3
# 68            69         1       3
# 71            72         0       3
# 78            79         1       2
# 84            85         1       2
# 86            87         0       3
# 111          112         0       3
# 114          115         0       3
# 119          120         0       3
# 125          126         1       3
# 138          139         0       3
# ...

# %%
ChiTrv[ChiTrv.Survived==1]
# Out:
#      PassengerId  Survived  Pclass  \
# 9             10         1       2
# 10            11         1       3
# 22            23         1       3
# 39            40         1       3
# 43            44         1       2
# 58            59         1       2
# 68            69         1       3
# 78            79         1       2
# 84            85         1       2
# 125          126         1       3
# 156          157         1       3
# 165          166         1       3
# 172          173         1       3
# 183          184         1       2
# 184          185         1       3
# 193          194         1       2
# 204          205         1       3
# 208          209         1       3
# 220          221         1       3
# 233          234         1       3
# 237          238         1       2
# 261          262         1       3
# 305          306         1       1
# 307          308         1       1
# 311          312         1       1
# ...

# %%
ChiTrv.Survived.hist()

# %% [markdown]
# ### Number of People Embarked at Southhompton(s)
# <li> CLasswise Histogram
# <li> Survivorship Histogram

# %%
EmbS=data[data.Embarked=='S']

# %%
EmbS
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 17            18         1       2
# 18            19         0       3
# 20            21         0       2
# 21            22         1       2
# 23            24         1       1
# 24            25         0       3
# 25            26         1       3
# 27            28         0       1
# 29            30         0       3
# 33            34         0       2
# 35            36         0       1
# 37            38         0       3
# ...

# %%
EmbS.Pclass.hist()

# %%
EmbS.Survived.hist()

# %% [markdown]
# ### People Death& Survived according to their Seating Class
# <li>1st Class Death & Survived
# <li>2st Class Death & Survived
# <li>3st Class Death & Survived

# %%
DetSer=data[(data.Survived>=0)]

# %%
DetSer
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...

# %%
import pandas as pd
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
data=pd.read_csv('train.csv')

# %%
EmbNu=data[data.Embarked.isnull()]

# %%
EmbNu
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 61            62         1       1                        Icard, Miss. Amelie
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN

# %%
c='S'

# %%
c
# Out:
# 'S'

# %%
data.Embarked = data.Embarked.fillna(value=c)

# %%
data[data.Embarked.isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# 5              6         0       3
# 6              7         0       1
# 7              8         0       3
# 8              9         1       3
# 9             10         1       2
# 10            11         1       3
# 11            12         1       1
# 12            13         0       3
# 13            14         0       3
# 14            15         0       3
# 15            16         1       2
# 16            17         0       3
# 17            18         1       2
# 18            19         0       3
# 19            20         1       3
# 20            21         0       2
# 21            22         1       2
# 22            23         1       3
# 23            24         1       1
# 24            25         0       3
# ...
